# %%
#importing important libraries
import pandas as pd
import numpy as ny
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the dataset by using pandas library
df=pd.read_csv("Incidents_Responded_to_by_Fire_Companies.csv")
# Out:
# E:\Python\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (1,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2518758 entries, 0 to 2518757
# Data columns (total 24 columns):
#  #   Column                        Dtype
# ---  ------                        -----
#  0   IM_INCIDENT_KEY               int64
#  1   FIRE_BOX                      object
#  2   INCIDENT_TYPE_DESC            object
#  3   INCIDENT_DATE_TIME            object
#  4   ARRIVAL_DATE_TIME             object
#  5   UNITS_ONSCENE                 float64
#  6   LAST_UNIT_CLEARED_DATE_TIME   object
#  7   HIGHEST_LEVEL_DESC            object
#  8   TOTAL_INCIDENT_DURATION       float64
#  9   ACTION_TAKEN1_DESC            object
#  10  ACTION_TAKEN2_DESC            object
#  11  ACTION_TAKEN3_DESC            object
#  12  PROPERTY_USE_DESC             object
#  13  STREET_HIGHWAY                object
#  14  ZIP_CODE                      object
#  15  BOROUGH_DESC                  object
#  16  FLOOR                         object
#  17  CO_DETECTOR_PRESENT_DESC      object
# ...

# %%
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         55672688     2147
# 1         55672692      818
# 2         55672693     9656
# 3         55672695     7412
# 4         55672697     4019
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0                  300 - Rescue, EMS incident, other  01/01/2013 12:00:20 AM
# 1  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:00:37 AM
# 2                  300 - Rescue, EMS incident, other  01/01/2013 12:01:17 AM
# 3                412 - Gas leak (natural gas or LPG)  01/01/2013 12:02:32 AM
# 4  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:01:49 AM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  01/01/2013 12:14:23 AM            1.0      01/01/2013 12:20:06 AM
# 1  01/01/2013 12:09:03 AM            3.0      01/01/2013 12:30:06 AM
# 2  01/01/2013 12:04:55 AM            1.0      01/01/2013 12:15:18 AM
# ...

# %%
df.isna().sum()
# Out:
# IM_INCIDENT_KEY                       0
# FIRE_BOX                             10
# INCIDENT_TYPE_DESC                    0
# INCIDENT_DATE_TIME                    0
# ARRIVAL_DATE_TIME                 62312
# UNITS_ONSCENE                     62523
# LAST_UNIT_CLEARED_DATE_TIME           2
# HIGHEST_LEVEL_DESC                  152
# TOTAL_INCIDENT_DURATION             149
# ACTION_TAKEN1_DESC                    0
# ACTION_TAKEN2_DESC              1983186
# ACTION_TAKEN3_DESC              2273503
# PROPERTY_USE_DESC                     6
# STREET_HIGHWAY                    38157
# ZIP_CODE                             12
# BOROUGH_DESC                          0
# FLOOR                           1975680
# CO_DETECTOR_PRESENT_DESC        2485756
# FIRE_ORIGIN_BELOW_GRADE_FLAG    2516700
# STORY_FIRE_ORIGIN_COUNT         2504526
# FIRE_SPREAD_DESC                2504527
# DETECTOR_PRESENCE_DESC          2504528
# AES_PRESENCE_DESC               2504528
# ...

# %%
df.drop(df.columns[[18,19,20,21,22,23,10,11]], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2518758 entries, 0 to 2518757
# Data columns (total 16 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   IM_INCIDENT_KEY              int64
#  1   FIRE_BOX                     object
#  2   INCIDENT_TYPE_DESC           object
#  3   INCIDENT_DATE_TIME           object
#  4   ARRIVAL_DATE_TIME            object
#  5   UNITS_ONSCENE                float64
#  6   LAST_UNIT_CLEARED_DATE_TIME  object
#  7   HIGHEST_LEVEL_DESC           object
#  8   TOTAL_INCIDENT_DURATION      float64
#  9   ACTION_TAKEN1_DESC           object
#  10  PROPERTY_USE_DESC            object
#  11  STREET_HIGHWAY               object
#  12  ZIP_CODE                     object
#  13  BOROUGH_DESC                 object
#  14  FLOOR                        object
#  15  CO_DETECTOR_PRESENT_DESC     object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 307.5+ MB

# %%
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         55672688     2147
# 1         55672692      818
# 2         55672693     9656
# 3         55672695     7412
# 4         55672697     4019
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0                  300 - Rescue, EMS incident, other  01/01/2013 12:00:20 AM
# 1  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:00:37 AM
# 2                  300 - Rescue, EMS incident, other  01/01/2013 12:01:17 AM
# 3                412 - Gas leak (natural gas or LPG)  01/01/2013 12:02:32 AM
# 4  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:01:49 AM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  01/01/2013 12:14:23 AM            1.0      01/01/2013 12:20:06 AM
# 1  01/01/2013 12:09:03 AM            3.0      01/01/2013 12:30:06 AM
# 2  01/01/2013 12:04:55 AM            1.0      01/01/2013 12:15:18 AM
# ...

# %%
df=df.replace(ny.nan, 0)

# %%
df.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX  \
# 0         55672688     2147
# 1         55672692      818
# 2         55672693     9656
# 3         55672695     7412
# 4         55672697     4019
#
#                                   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 0                  300 - Rescue, EMS incident, other  01/01/2013 12:00:20 AM
# 1  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:00:37 AM
# 2                  300 - Rescue, EMS incident, other  01/01/2013 12:01:17 AM
# 3                412 - Gas leak (natural gas or LPG)  01/01/2013 12:02:32 AM
# 4  735A - Unwarranted alarm/defective condition o...  01/01/2013 12:01:49 AM
#
#         ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 0  01/01/2013 12:14:23 AM            1.0      01/01/2013 12:20:06 AM
# 1  01/01/2013 12:09:03 AM            3.0      01/01/2013 12:30:06 AM
# 2  01/01/2013 12:04:55 AM            1.0      01/01/2013 12:15:18 AM
# ...

# %%
df.isna().sum()
# Out:
# IM_INCIDENT_KEY                0
# FIRE_BOX                       0
# INCIDENT_TYPE_DESC             0
# INCIDENT_DATE_TIME             0
# ARRIVAL_DATE_TIME              0
# UNITS_ONSCENE                  0
# LAST_UNIT_CLEARED_DATE_TIME    0
# HIGHEST_LEVEL_DESC             0
# TOTAL_INCIDENT_DURATION        0
# ACTION_TAKEN1_DESC             0
# PROPERTY_USE_DESC              0
# STREET_HIGHWAY                 0
# ZIP_CODE                       0
# BOROUGH_DESC                   0
# FLOOR                          0
# CO_DETECTOR_PRESENT_DESC       0
# dtype: int64

# %%
df.describe()
# Out:
#        IM_INCIDENT_KEY  UNITS_ONSCENE  TOTAL_INCIDENT_DURATION
# count     2.518758e+06   2.518758e+06             2.518758e+06
# mean      5.926416e+07   2.065755e+00             1.442086e+03
# std       2.242052e+06   1.893915e+00             4.519337e+04
# min       5.567269e+07   0.000000e+00             0.000000e+00
# 25%       5.730752e+07   1.000000e+00             7.420000e+02
# 50%       5.911952e+07   1.000000e+00             1.036000e+03
# 75%       6.113234e+07   3.000000e+00             1.523000e+03
# max       6.347677e+07   2.070000e+02             7.101136e+07

# %%
df1 = pd.value_counts(df['INCIDENT_TYPE_DESC'])/sum(pd.value_counts(df['INCIDENT_TYPE_DESC']))*100
data2 = {'Incident_type': df1.keys(),'Ratio': df1[df1.keys()]}
df2 = pd.DataFrame(data2)
df2 = df2[df2['Ratio']>0.7]
r = 100-df2['Ratio'].sum()
labels = df2['Incident_type'].unique()

# %%
pie, ax = plt.subplots(figsize=[20,20])
labels = df2['Incident_type'].unique()
plt.pie(x=df2['Ratio'], autopct="%.1f%%", labels=labels, pctdistance=.6,startangle=70)
plt.title("Types of incidents", fontsize=15);
plt.show()

# %% [markdown]
# Rescue, EMS incident, other is the most common type of incident

# %%
df['BOROUGH_DESC'].value_counts()
# Out:
# 4 - Brooklyn         731297
# 1 - Manhattan        641825
# 5 - Queens           509106
# 2 - Bronx            505899
# 3 - Staten Island    130631
# Name: BOROUGH_DESC, dtype: int64

# %%
df1=df.loc[(df['INCIDENT_TYPE_DESC'] == '710 - Malicious, mischievous false call, other')]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 129466 entries, 9 to 2518752
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   IM_INCIDENT_KEY              129466 non-null  int64
#  1   FIRE_BOX                     129466 non-null  object
#  2   INCIDENT_TYPE_DESC           129466 non-null  object
#  3   INCIDENT_DATE_TIME           129466 non-null  object
#  4   ARRIVAL_DATE_TIME            129466 non-null  object
#  5   UNITS_ONSCENE                129466 non-null  float64
#  6   LAST_UNIT_CLEARED_DATE_TIME  129466 non-null  object
#  7   HIGHEST_LEVEL_DESC           129466 non-null  object
#  8   TOTAL_INCIDENT_DURATION      129466 non-null  float64
#  9   ACTION_TAKEN1_DESC           129466 non-null  object
#  10  PROPERTY_USE_DESC            129466 non-null  object
#  11  STREET_HIGHWAY               129466 non-null  object
# ...

# %%
df1['INCIDENT_TYPE_DESC'].value_counts()
# Out:
# 710 - Malicious, mischievous false call, other    129466
# Name: INCIDENT_TYPE_DESC, dtype: int64

# %%
sns.countplot(x=df1['BOROUGH_DESC'])
plt.rcParams['figure.figsize']=(20,10)

# %% [markdown]
# Manhattan contain most of the malicious calls

# %%
df2=df.loc[(df['INCIDENT_TYPE_DESC'] == '113 - Cooking fire, confined to container')]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96142 entries, 53 to 2518664
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IM_INCIDENT_KEY              96142 non-null  int64
#  1   FIRE_BOX                     96142 non-null  object
#  2   INCIDENT_TYPE_DESC           96142 non-null  object
#  3   INCIDENT_DATE_TIME           96142 non-null  object
#  4   ARRIVAL_DATE_TIME            96142 non-null  object
#  5   UNITS_ONSCENE                96142 non-null  float64
#  6   LAST_UNIT_CLEARED_DATE_TIME  96142 non-null  object
#  7   HIGHEST_LEVEL_DESC           96142 non-null  object
#  8   TOTAL_INCIDENT_DURATION      96142 non-null  float64
#  9   ACTION_TAKEN1_DESC           96142 non-null  object
#  10  PROPERTY_USE_DESC            96142 non-null  object
#  11  STREET_HIGHWAY               96142 non-null  object
# ...

# %%
df2.head()
# Out:
#      IM_INCIDENT_KEY FIRE_BOX                         INCIDENT_TYPE_DESC  \
# 53          55672876     1380  113 - Cooking fire, confined to container
# 58          55672892     1201  113 - Cooking fire, confined to container
# 121         55673073     2538  113 - Cooking fire, confined to container
# 250         55673417      688  113 - Cooking fire, confined to container
# 330         55673603      574  113 - Cooking fire, confined to container
#
#          INCIDENT_DATE_TIME       ARRIVAL_DATE_TIME  UNITS_ONSCENE  \
# 53   01/01/2013 12:34:10 AM  01/01/2013 12:37:52 AM            3.0
# 58   01/01/2013 12:38:51 AM  01/01/2013 12:42:40 AM            6.0
# 121  01/01/2013 01:23:26 AM  01/01/2013 01:27:05 AM            5.0
# 250  01/01/2013 03:00:44 AM  01/01/2013 03:06:52 AM            5.0
# 330  01/01/2013 04:16:58 AM  01/01/2013 04:20:21 AM            5.0
#
#     LAST_UNIT_CLEARED_DATE_TIME  \
# 53       01/01/2013 12:49:43 AM
# 58       01/01/2013 12:57:58 AM
# ...

# %%
df2['Date'] = pd.to_datetime(df2['INCIDENT_DATE_TIME']).dt.date
df2['Time'] = pd.to_datetime(df2['INCIDENT_DATE_TIME']).dt.time
# Out:
# <ipython-input-23-1d2a0f1dcf2a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Date'] = pd.to_datetime(df2['INCIDENT_DATE_TIME']).dt.date
# <ipython-input-23-1d2a0f1dcf2a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Time'] = pd.to_datetime(df2['INCIDENT_DATE_TIME']).dt.time

# %%
df2['Time'] = df2['Time'].replace(r':', '.', regex=True)
# Out:
# <ipython-input-24-f0e79864191a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Time'] = df2['Time'].replace(r':', '.', regex=True)

# %%
df2['hour'] = pd.to_datetime(df2['Time'], format='%H:%M:%S').dt.hour
# Out:
# <ipython-input-25-54b4fafedbd3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['hour'] = pd.to_datetime(df2['Time'], format='%H:%M:%S').dt.hour

# %%
sns.countplot(x=df2['hour'])
plt.rcParams['figure.figsize']=(20,10)

# %% [markdown]
# At 18:00 most of the cases occur while cooking

# %%
df3=df.loc[(df['INCIDENT_TYPE_DESC'] == '111 - Building fire')]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14202 entries, 91 to 2518263
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   IM_INCIDENT_KEY              14202 non-null  int64
#  1   FIRE_BOX                     14202 non-null  object
#  2   INCIDENT_TYPE_DESC           14202 non-null  object
#  3   INCIDENT_DATE_TIME           14202 non-null  object
#  4   ARRIVAL_DATE_TIME            14202 non-null  object
#  5   UNITS_ONSCENE                14202 non-null  float64
#  6   LAST_UNIT_CLEARED_DATE_TIME  14202 non-null  object
#  7   HIGHEST_LEVEL_DESC           14202 non-null  object
#  8   TOTAL_INCIDENT_DURATION      14202 non-null  float64
#  9   ACTION_TAKEN1_DESC           14202 non-null  object
#  10  PROPERTY_USE_DESC            14202 non-null  object
#  11  STREET_HIGHWAY               14202 non-null  object
# ...

# %%
a=df3['UNITS_ONSCENE'].mean()

# %%
df4=df.loc[(df['INCIDENT_TYPE_DESC'] == '651 - Smoke scare, odor of smoke')]

# %%
b=df4['UNITS_ONSCENE'].mean()

# %%
e=a/b

# %%
f=round(e,1)

# %%
from fractions import Fraction

z = Fraction(f).limit_denominator()
print(z)
# Out:
# 14/5

# %% [markdown]
# 14/5 is the ratio of the average number of units that arrive to a scene of an incident classified as ‘111-Building fire’ to the number that arrive for ‘651-Smoke scare, odor of smoke’

# %%
df3['Time'] = pd.to_datetime(df3['INCIDENT_DATE_TIME']).dt.time
# Out:
# <ipython-input-35-eb6e47dd19e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Time'] = pd.to_datetime(df3['INCIDENT_DATE_TIME']).dt.time

# %%
df3['minute_incident'] = pd.to_datetime(df3['Time'], format='%H:%M:%S').dt.minute
# Out:
# <ipython-input-36-78e84ccc912d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['minute_incident'] = pd.to_datetime(df3['Time'], format='%H:%M:%S').dt.minute

# %%
df3
# Out:
#          IM_INCIDENT_KEY FIRE_BOX   INCIDENT_TYPE_DESC  \
# 91              55672965     2595  111 - Building fire
# 199             55673299     2591  111 - Building fire
# 440             55673870     1601  111 - Building fire
# 492             55674012     7973  111 - Building fire
# 569             55674170     1726  111 - Building fire
# ...                  ...      ...                  ...
# 2517681         63472868     2807  111 - Building fire
# 2517770         63473162     2386  111 - Building fire
# 2518063         63474272     2660  111 - Building fire
# 2518123         63474545      662  111 - Building fire
# 2518263         63475053      810  111 - Building fire
#
#              INCIDENT_DATE_TIME       ARRIVAL_DATE_TIME  UNITS_ONSCENE  \
# 91       01/01/2013 12:58:10 AM  01/01/2013 01:00:50 AM           15.0
# 199      01/01/2013 02:22:56 AM  01/01/2013 02:25:23 AM            9.0
# 440      01/01/2013 06:20:49 AM  01/01/2013 06:26:13 AM           23.0
# ...

# %%
df3['Time2'] = pd.to_datetime(df3['ARRIVAL_DATE_TIME']).dt.time
# Out:
# <ipython-input-38-f485128f59b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['Time2'] = pd.to_datetime(df3['ARRIVAL_DATE_TIME']).dt.time

# %%
df3['minute_arrival'] = pd.to_datetime(df3['Time2'], format='%H:%M:%S').dt.minute
# Out:
# <ipython-input-39-4af0f2bc0e0c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['minute_arrival'] = pd.to_datetime(df3['Time2'], format='%H:%M:%S').dt.minute

# %%
df3.head()
# Out:
#      IM_INCIDENT_KEY FIRE_BOX   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 91          55672965     2595  111 - Building fire  01/01/2013 12:58:10 AM
# 199         55673299     2591  111 - Building fire  01/01/2013 02:22:56 AM
# 440         55673870     1601  111 - Building fire  01/01/2013 06:20:49 AM
# 492         55674012     7973  111 - Building fire  01/01/2013 07:59:48 AM
# 569         55674170     1726  111 - Building fire  01/01/2013 09:47:27 AM
#
#           ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 91   01/01/2013 01:00:50 AM           15.0      01/01/2013 04:15:20 AM
# 199  01/01/2013 02:25:23 AM            9.0      01/01/2013 07:29:44 AM
# 440  01/01/2013 06:26:13 AM           23.0      01/01/2013 10:32:28 AM
# 492  01/01/2013 08:03:33 AM            6.0      01/01/2013 08:19:37 AM
# 569  01/01/2013 09:49:25 AM           13.0      01/01/2013 11:11:42 AM
#
#                                     HIGHEST_LEVEL_DESC  \
# ...

# %%
df3['diff']=df3['minute_arrival']-df3['minute_incident']
# Out:
# <ipython-input-41-2c5fdf9bb954>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['diff']=df3['minute_arrival']-df3['minute_incident']

# %%
df3.head()
# Out:
#      IM_INCIDENT_KEY FIRE_BOX   INCIDENT_TYPE_DESC      INCIDENT_DATE_TIME  \
# 91          55672965     2595  111 - Building fire  01/01/2013 12:58:10 AM
# 199         55673299     2591  111 - Building fire  01/01/2013 02:22:56 AM
# 440         55673870     1601  111 - Building fire  01/01/2013 06:20:49 AM
# 492         55674012     7973  111 - Building fire  01/01/2013 07:59:48 AM
# 569         55674170     1726  111 - Building fire  01/01/2013 09:47:27 AM
#
#           ARRIVAL_DATE_TIME  UNITS_ONSCENE LAST_UNIT_CLEARED_DATE_TIME  \
# 91   01/01/2013 01:00:50 AM           15.0      01/01/2013 04:15:20 AM
# 199  01/01/2013 02:25:23 AM            9.0      01/01/2013 07:29:44 AM
# 440  01/01/2013 06:26:13 AM           23.0      01/01/2013 10:32:28 AM
# 492  01/01/2013 08:03:33 AM            6.0      01/01/2013 08:19:37 AM
# 569  01/01/2013 09:49:25 AM           13.0      01/01/2013 11:11:42 AM
#
#                                     HIGHEST_LEVEL_DESC  \
# ...

# %%
df3.describe()
# Out:
#        IM_INCIDENT_KEY  UNITS_ONSCENE  TOTAL_INCIDENT_DURATION  \
# count     1.420200e+04   14202.000000             14202.000000
# mean      5.894770e+07      11.098437              7487.319462
# std       2.241345e+06       7.469726             13342.278133
# min       5.567296e+07       0.000000                 0.000000
# 25%       5.694988e+07       6.000000              3221.000000
# 50%       5.862577e+07      10.000000              5916.000000
# 75%       6.075881e+07      13.000000              8636.750000
# max       6.347505e+07     207.000000            491391.000000
#
#        minute_incident  minute_arrival          diff
# count     14202.000000    14202.000000  14202.000000
# mean         29.267779       29.274539      0.006760
# std          17.317309       17.322196     14.179673
# min           0.000000        0.000000    -59.000000
# 25%          14.000000       14.000000      3.000000
# 50%          29.000000       29.000000      3.000000
# ...

# %% [markdown]
# 4 is the third quartile of the distribution

# %%
zip1=pd.read_excel("zip.xlsx")

# %%
zip1
# Out:
#                      ZIP_CODE  Population
# 0                       11368      108661
# 1                       11385      105025
# 2                       11211      104561
# 3                       11208      102626
# 4                       10467      100867
# ...                       ...         ...
# 1594                    14854          14
# 1595  13475, 13623, and 12864          13
# 1596                    14529          12
# 1597          13352 and 12007          10
# 1598                    13677           6
#
# [1599 rows x 2 columns]

# %%
df4=  pd.merge(df,zip1 , on='ZIP_CODE')

# %%
df4.head()
# Out:
#    IM_INCIDENT_KEY FIRE_BOX                          INCIDENT_TYPE_DESC  \
# 0         55672688     2147           300 - Rescue, EMS incident, other
# 1         55673482     2147           300 - Rescue, EMS incident, other
# 2         55673584     2172           300 - Rescue, EMS incident, other
# 3         55673931     2115  322 - Motor vehicle accident with injuries
# 4         55673971     2163           300 - Rescue, EMS incident, other
#
#        INCIDENT_DATE_TIME       ARRIVAL_DATE_TIME  UNITS_ONSCENE  \
# 0  01/01/2013 12:00:20 AM  01/01/2013 12:14:23 AM            1.0
# 1  01/01/2013 03:24:39 AM  01/01/2013 03:29:22 AM            1.0
# 2  01/01/2013 04:09:03 AM  01/01/2013 04:13:49 AM            1.0
# 3  01/01/2013 06:57:07 AM  01/01/2013 07:01:33 AM            2.0
# 4  01/01/2013 07:30:55 AM  01/01/2013 07:36:39 AM            1.0
#
#   LAST_UNIT_CLEARED_DATE_TIME  \
# 0      01/01/2013 12:20:06 AM
# 1      01/01/2013 03:53:30 AM
# 2      01/01/2013 05:28:44 AM
# ...

# %%
df['Time_clear'] = pd.to_datetime(df['LAST_UNIT_CLEARED_DATE_TIME']).dt.time

# %%
df['minute_clear'] = pd.to_datetime(df['Time_clear'], format='%H:%M:%S').dt.minute

# %%
contigency= pd.crosstab(df['CO_DETECTOR_PRESENT_DESC'], df['minute_clear']) 
contigency
# Out:
# minute_clear                 0      1      2      3      4      5      6   \
# CO_DETECTOR_PRESENT_DESC
# 0                         43571  42427  42230  41827  41671  42086  41747
# No                           96    121     95    106    117    107     93
# Yes                         442    438    435    457    466    455    421
#
# minute_clear                 7      8      9   ...     50     51     52  \
# CO_DETECTOR_PRESENT_DESC                       ...
# 0                         41329  41743  41364  ...  41015  41632  40827
# No                          100    113    107  ...    121    107    118
# Yes                         467    461    420  ...    419    464    444
#
# minute_clear                 53     54     55     56     57     58     59
# CO_DETECTOR_PRESENT_DESC
# 0                         41051  40912  41464  41052  41330  40842  41288
# No                          115    113    113     84    115     99     94
# ...

# %%
contigency_pct = pd.crosstab(df['CO_DETECTOR_PRESENT_DESC'], df['minute_clear'], normalize='index')
contigency_pct
# Out:
# minute_clear                    0         1         2         3         4   \
# CO_DETECTOR_PRESENT_DESC
# 0                         0.017528  0.017068  0.016989  0.016827  0.016764
# No                        0.015304  0.019289  0.015144  0.016898  0.018651
# Yes                       0.016536  0.016387  0.016274  0.017098  0.017434
#
# minute_clear                    5         6         7         8         9   \
# CO_DETECTOR_PRESENT_DESC
# 0                         0.016931  0.016794  0.016626  0.016793  0.016640
# No                        0.017057  0.014825  0.015941  0.018014  0.017057
# Yes                       0.017023  0.015751  0.017472  0.017247  0.015713
#
# minute_clear              ...        50        51        52        53  \
# CO_DETECTOR_PRESENT_DESC  ...
# 0                         ...  0.016500  0.016748  0.016424  0.016514
# No                        ...  0.019289  0.017057  0.018811  0.018333
# ...

# %%
plt.figure(figsize=(12,8)) 
sns.heatmap(contigency, annot=True, cmap="YlGnBu")

# %% [markdown]
# There is no incident that is lasting longer than 60 minutes
